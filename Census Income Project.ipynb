# %%
#Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn 
# %matplotlib inline

# %%
#Importing the data from the file

# %%
#FETCHING DATA

# %%
df=pd.read_csv(r"C:/Users/Vidhya/Downloads/census_income.csv")

# %%
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# ...

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
#With describe, we get all the mathematical details of the dataset

# %%
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
#Our data has 32560 rows and 15 columns

# %%
#Categorical attributes are workclass, Education, marital-status, Occupation,Relationship,Race,Sex and native-country.
#Continuous attributes are Age, Education, Fnlwgt,capital-gain,capital-loss,hours-per-week

# %%
#Getting the information of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
#DATA CLEANING

# %%
#Checking for null values

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
#There are no null values in our data

# %%
#Dropping NAs and converting certain attributes to float datatype

# %%
df.Age = df.Age.astype(float)
df['Hours_per_week'] = df['Hours_per_week'].astype(float)

# %%
#Dropping NA values

# %%
df_new = df.dropna()
df_new['predclass'] = df_new['Income']
del df_new['Income']
df_new['Educational_num'] = df_new['Education_num']
del df_new['Education_num']

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              32560 non-null  float64
#  1   Workclass        32560 non-null  object
#  2   Fnlwgt           32560 non-null  int64
#  3   Education        32560 non-null  object
#  4   Marital_status   32560 non-null  object
#  5   Occupation       32560 non-null  object
#  6   Relationship     32560 non-null  object
#  7   Race             32560 non-null  object
#  8   Sex              32560 non-null  object
#  9   Capital_gain     32560 non-null  int64
#  10  Capital_loss     32560 non-null  int64
#  11  Hours_per_week   32560 non-null  float64
#  12  Native_country   32560 non-null  object
#  13  predclass        32560 non-null  object
#  14  Educational_num  32560 non-null  int64
# dtypes: float64(2), int64(4), object(9)
# memory usage: 4.0+ MB

# %%
df_new.isnull().sum()
# Out:
# Age                0
# Workclass          0
# Fnlwgt             0
# Education          0
# Marital_status     0
# Occupation         0
# Relationship       0
# Race               0
# Sex                0
# Capital_gain       0
# Capital_loss       0
# Hours_per_week     0
# Native_country     0
# predclass          0
# Educational_num    0
# dtype: int64

# %%
#Finding out the unique values

# %%
print('Workclass',df_new.Workclass.unique())
print('Education',df_new.Education.unique())
print('Marital_status',df_new['Marital_status'].unique())
print('Occupation',df_new.Occupation.unique())
print('Relationship',df_new.Relationship.unique())
print('Race',df_new.Race.unique())
print('Sex',df_new.Sex.unique())
print('Native_country',df_new['Native_country'].unique())
print('predclass',df_new.predclass.unique())
# Out:
# Workclass [' Self-emp-not-inc' ' Private' ' State-gov' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']
# Education [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
# Marital_status [' Married-civ-spouse' ' Divorced' ' Married-spouse-absent'
#  ' Never-married' ' Separated' ' Married-AF-spouse' ' Widowed']
# Occupation [' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
#  ' Other-service' ' Adm-clerical' ' Sales' ' Craft-repair'
#  ' Transport-moving' ' Farming-fishing' ' Machine-op-inspct'
#  ' Tech-support' ' ?' ' Protective-serv' ' Armed-Forces'
#  ' Priv-house-serv']
# Relationship [' Husband' ' Not-in-family' ' Wife' ' Own-child' ' Unmarried'
#  ' Other-relative']
# Race [' White' ' Black' ' Asian-Pac-Islander' ' Amer-Indian-Eskimo' ' Other']
# Sex [' Male' ' Female']
# ...

# %%
figure = plt.figure(figsize=(20,2))
sns.countplot(y="predclass", data=df_new)
# Out:
# <AxesSubplot:xlabel='count', ylabel='predclass'>

# %%
#We see that our data is skewed towards income greater than 50K group

# %%
df_new['Education'].replace('Preschool', 'dropout',inplace=True)
df_new['Education'].replace('10th', 'dropout',inplace=True)
df_new['Education'].replace('11th', 'dropout',inplace=True)
df_new['Education'].replace('12th', 'dropout',inplace=True)
df_new['Education'].replace('1st-4th', 'dropout',inplace=True)
df_new['Education'].replace('5th-6th', 'dropout',inplace=True)
df_new['Education'].replace('7th-8th', 'dropout',inplace=True)
df_new['Education'].replace('9th', 'dropout',inplace=True)
df_new['Education'].replace('HS-Grad', 'HighGrad',inplace=True)
df_new['Education'].replace('HS-grad', 'HighGrad',inplace=True)
df_new['Education'].replace('Some-college', 'CommunityCollege',inplace=True)
df_new['Education'].replace('Assoc-acdm', 'CommunityCollege',inplace=True)
df_new['Education'].replace('Assoc-voc', 'CommunityCollege',inplace=True)
df_new['Education'].replace('Bachelors', 'Bachelors',inplace=True)
df_new['Education'].replace('Masters', 'Masters',inplace=True)
df_new['Education'].replace('Prof-school', 'Masters',inplace=True)
df_new['Education'].replace('Doctorate', 'Doctorate',inplace=True)

# %%
df_new[['Education','Educational_num']].groupby(['Education'], as_index=False).mean().sort_values(by='Educational_num', ascending=False)
# Out:
#         Education  Educational_num
# 10      Doctorate               16
# 14    Prof-school               15
# 12        Masters               14
# 9       Bachelors               13
# 7      Assoc-acdm               12
# 8       Assoc-voc               11
# 15   Some-college               10
# 11        HS-grad                9
# 2            12th                8
# 1            11th                7
# 0            10th                6
# 6             9th                5
# 5         7th-8th                4
# 4         5th-6th                3
# 3         1st-4th                2
# 13      Preschool                1

# %%
figure = plt.figure(figsize=(20,5))
sns.countplot(y="Education", data=df_new)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Education'>

# %%
#We see that HS Grade has the highest count and Preschool has the least count

# %%
df_new['Marital_status'].replace('Never-married', 'NotMarried',inplace=True)
df_new['Marital_status'].replace(['Married-AF-spouse'], 'Married',inplace=True)
df_new['Marital_status'].replace(['Married-civ-spouse'], 'Married',inplace=True)
df_new['Marital_status'].replace(['Married-spouse-absent'], 'NotMarried',inplace=True)
df_new['Marital_status'].replace(['Separated'], 'Separated',inplace=True)
df_new['Marital_status'].replace(['Divorced'], 'Separated',inplace=True)
df_new['Marital_status'].replace(['Widowed'], 'Widowed',inplace=True)

# %%
figure = plt.figure(figsize=(20,4))
sns.countplot(y="Marital_status", data=df_new)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Marital_status'>

# %%
#We see that Married-civ-spouse has the most count and Married-AF-spouse has the least

# %%
plt.figure(figsize=(20,4)) 
sns.countplot(y="Occupation", data=df_new)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Occupation'>

# %%
#We see that Exec-managerial has the most count and Armed forces has the least

# %%
plt.figure(figsize=(20,4)) 
sns.countplot(y="Workclass", data=df_new)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Workclass'>

# %%
#We see that Private has the highest count and Without Pay, Never Worked had the least

# %%
df_new['age_bin'] = pd.cut(df_new['Age'], 20)

# %%
figure = plt.figure(figsize=(20,5)) 
plt.subplot(1, 2, 1)
sns.countplot(y="age_bin", data=df_new)
plt.subplot(1, 2, 2)
sns.distplot(df_new[df_new['predclass'] == '>50K']['Age'], kde_kws={"label": ">$50K"})
sns.distplot(df_new[df_new['predclass'] == '<=50K']['Age'], kde_kws={"label": "<=$50K"})
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
import warnings
warnings.simplefilter("ignore")

# %%
df_new[['predclass', 'Age']].groupby(['predclass'], as_index=False).mean().sort_values(by='Age', ascending=False)
# Out:
#   predclass        Age
# 1      >50K  44.249841
# 0     <=50K  36.783648

# %%
x, y, hue = "Race", "prop", "Sex"
plt.figure(figsize=(20,5)) 
f, axes = plt.subplots(1, 2)
sns.countplot(x=x, hue=hue, data=df_new, ax=axes[0])

prop_df = (df_new[x]
           .groupby(df_new[hue])
           .value_counts(normalize=True)
           .rename(y)
           .reset_index())

sns.barplot(x=x, y=y, hue=hue, data=prop_df, ax=axes[1])
# Out:
# <AxesSubplot:xlabel='Race', ylabel='prop'>

# %%
df_new['Hours_per_week_bin'] = pd.cut(df_new['Hours_per_week'], 10)
df_new['Hours_per_week'] = df_new['Hours_per_week']

# %%
figure = plt.figure(figsize=(20,8)) 
plt.subplot(1, 2, 1)
sns.countplot(y="Hours_per_week_bin", data=df_new);
plt.subplot(1, 2, 2)
sns.distplot(df_new['Hours_per_week']);
sns.distplot(df_new[df_new['predclass'] == '>50K']['Hours_per_week'], kde_kws={"label": ">$50K"})
sns.distplot(df_new[df_new['predclass'] == '<=50K']['Hours_per_week'], kde_kws={"label": "<$50K"})
plt.ylim(0, None)
# Out:
# (0.0, 0.2509762197262196)

# %%
#We see that the graph is a normalised distriution curve

# %%
#Creating  a crossing feature: Age + hour of work

# %%
g = sns.jointplot(x = 'Age', 
              y = 'Hours_per_week',
              data = df_new, 
              kind = 'hex', 
              cmap= 'hot', 
              size=12)
sns.regplot(df_new.Age, df_new['Hours_per_week'], ax=g.ax_joint, scatter=False, color='red')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Hours_per_week'>

# %%
df_new.head()
# Out:
#     Age          Workclass  Fnlwgt   Education       Marital_status  \
# 0  50.0   Self-emp-not-inc   83311   Bachelors   Married-civ-spouse
# 1  38.0            Private  215646     HS-grad             Divorced
# 2  53.0            Private  234721        11th   Married-civ-spouse
# 3  28.0            Private  338409   Bachelors   Married-civ-spouse
# 4  37.0            Private  284582     Masters   Married-civ-spouse
#
#            Occupation    Relationship    Race      Sex  Capital_gain  \
# 0     Exec-managerial         Husband   White     Male             0
# 1   Handlers-cleaners   Not-in-family   White     Male             0
# 2   Handlers-cleaners         Husband   Black     Male             0
# 3      Prof-specialty            Wife   Black   Female             0
# 4     Exec-managerial            Wife   White   Female             0
#
#    Capital_loss  Hours_per_week  Native_country predclass  Educational_num  \
# ...

# %%
#Crossing numerical values

# %%
df_new['age-hours'] = df_new['Age']*df_new['Hours_per_week']
df_new['age-hours_bin'] = pd.cut(df_new['age-hours'], 10)

# %%
figure = plt.figure(figsize=(20,10)) 
plt.subplot(1, 2, 1)
sns.countplot(y="age-hours_bin", data=df_new);
plt.subplot(1, 2, 2)
sns.distplot(df_new[df_new['predclass'] == '>50K']['age-hours'], kde_kws={"label": ">$50K"})
sns.distplot(df_new[df_new['predclass'] == '<=50K']['age-hours'], kde_kws={"label": "<$50K"})
# Out:
# <AxesSubplot:xlabel='age-hours'>

# %%
#Plotting pair plots for complete data

# %%
pp = sns.pairplot(df_new, hue = 'predclass', 
                  size=4, diag_kind = 'kde', diag_kws=dict(shade=True), plot_kws=dict(s=30) )
pp.set(xticklabels=[])

# %%
#Plotting correlation heatmap

# %%
def correlation_heatmap(df):
    _ , ax = plt.subplots(figsize =(14, 12))
    colormap = sns.diverging_palette(220, 10, as_cmap = True)
    sns.heatmap(
        df.corr(), 
        cmap = "YlGn",
        square=True, 
        cbar_kws={'shrink':.9 }, 
        ax=ax,
        annot=True, 
        linewidths=0.1,vmax=1.0, linecolor='blue',
        annot_kws={'fontsize':14 }
    )
    
    plt.title('Pearson Correlation of Features', y=1.05, size=17)

correlation_heatmap(df_new)

# %%
#We see that age, age-hours and hours per week have the most relation with each other

# %%
df_new.tail()
# Out:
#         Age      Workclass  Fnlwgt    Education       Marital_status  \
# 32555  27.0        Private  257302   Assoc-acdm   Married-civ-spouse
# 32556  40.0        Private  154374      HS-grad   Married-civ-spouse
# 32557  58.0        Private  151910      HS-grad              Widowed
# 32558  22.0        Private  201490      HS-grad        Never-married
# 32559  52.0   Self-emp-inc  287927      HS-grad   Married-civ-spouse
#
#                Occupation Relationship    Race      Sex  Capital_gain  \
# 32555        Tech-support         Wife   White   Female             0
# 32556   Machine-op-inspct      Husband   White     Male             0
# 32557        Adm-clerical    Unmarried   White   Female             0
# 32558        Adm-clerical    Own-child   White     Male             0
# 32559     Exec-managerial         Wife   White   Female         15024
#
#        Capital_loss  Hours_per_week  Native_country predclass  \
# 32555             0            38.0   United-States     <=50K
# ...

# %%
import math

# %%
def plot_bivariate_bar(dataset, hue, cols=5, width=22, height=16, hspace=0.2, wspace=0.5):
    dataset = dataset.select_dtypes(include=[np.object])
    figure = plt.figure(figsize=(width,height))
    figure.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=wspace, hspace=hspace)
    rows = math.ceil(float(dataset.shape[1]) / cols)
    for i, column in enumerate(dataset.columns):
        ax = figure.add_subplot(rows, cols, i + 1)
        ax.set_title(column)
        if dataset.dtypes[column] == np.object:
            g = sns.countplot(y=column, hue=hue, data=dataset)
            substrings = [s.get_text()[:10] for s in g.get_yticklabels()]
            g.set(yticklabels=substrings)
bivariate_df = df_new.loc[:, ['Workclass', 'Education', 
           'Marital_status', 'Occupation', 
           'Relationship', 'Race', 'Sex','predclass']]  
plot_bivariate_bar(bivariate_df, hue='predclass', cols=2, width=22, height=16, hspace=0.4, wspace=0.5)

# %%
#We got the plots for 'Workclass', 'Education', 'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex','predclass

# %%
#Comparing Occupation and Income level

# %%
from matplotlib import pyplot
a4_dims = (20, 6)
figure, ax = pyplot.subplots(figsize=a4_dims)
ax = sns.violinplot(x="Occupation", y="Age", hue="predclass",
                    data=df_new, gridsize=100, palette="muted", split=True, saturation=0.75)
ax
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='Age'>

# %%
#We see that senior workers have higher salaries and Armed Forces do not have high salaries
#Private house sector has highest age variation range but payment is not that high compared to others

# %%
#Comparing Race and Income Levelfrom matplotlib import pyplot

# %%
from matplotlib import pyplot
a4_dims = (20, 5)
figure, ax = pyplot.subplots(figsize=a4_dims)
ax = sns.violinplot(x="Race", y="Age", hue="predclass",
                    data=df_new, gridsize=100, palette="muted", split=True, saturation=0.75)
ax
# Out:
# <AxesSubplot:xlabel='Race', ylabel='Age'>

# %%
#We see that Amer Indian Eskimo has the highest <=50k and >50k

# %%
#BUILDING MODELS

# %%
from sklearn.cluster import KMeans
from matplotlib import cm
from sklearn.metrics import silhouette_samples
from sklearn.metrics import silhouette_score
from sklearn.metrics import accuracy_score

# %%
from sklearn.decomposition import PCA
from pandas.plotting import scatter_matrix
from mpl_toolkits.mplot3d import Axes3D

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import svm 
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB 
from sklearn.tree import DecisionTreeClassifier 
from sklearn import metrics 
from sklearn.metrics import confusion_matrix

# %%
#FEATURE ENCODING

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
df_new = df_new.apply(LabelEncoder().fit_transform)
df_new.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Marital_status  Occupation  \
# 0   33          6    2925          9               2           4
# 1   21          4   14085         11               0           6
# 2   36          4   15335          1               2           6
# 3   11          4   19354          9               2          10
# 4   20          4   17699         12               2           4
#
#    Relationship  Race  Sex  Capital_gain  Capital_loss  Hours_per_week  \
# 0             0     4    1             0             0              12
# 1             1     4    1             0             0              39
# 2             0     2    1             0             0              39
# 3             5     2    0             0             0              39
# 4             5     4    0             0             0              39
#
#    Native_country  predclass  Educational_num  age_bin  Hours_per_week_bin  \
# ...

# %%
#USing Train Test Split

# %%
drop_elements = ['Education', 'Native_country', 'predclass', 'age_bin', 'age-hours_bin','Hours_per_week_bin']
y = df_new["predclass"]
X = df_new.drop(drop_elements, axis=1)
X.head()
# Out:
#    Age  Workclass  Fnlwgt  Marital_status  Occupation  Relationship  Race  \
# 0   33          6    2925               2           4             0     4
# 1   21          4   14085               0           6             1     4
# 2   36          4   15335               2           6             0     2
# 3   11          4   19354               2          10             5     2
# 4   20          4   17699               2           4             5     4
#
#    Sex  Capital_gain  Capital_loss  Hours_per_week  Educational_num  age-hours
# 0    1             0             0              12               12        290
# 1    1             0             0              39                8        620
# 2    1             0             0              39                6        810
# 3    0             0             0              39               12        477
# 4    0             0             0              39               13        606

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
#Principal Component Analysis (PCA) using StandardScaler

# %%
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# %%
std_sclr = preprocessing.StandardScaler().fit(df_new.drop('predclass', axis=1))
X = std_sclr.transform(df_new.drop('predclass', axis=1))
y = df_new['predclass']

# %%
target_names = [0,1]
colors = ['green','pink','blue']
lw = 2
alpha = 0.3
plt.figure(2, figsize=(20, 8))
plt.subplot(1, 2, 1)
pca = PCA(n_components=2)
X_r = pca.fit(X).transform(X)
for color, i, target_name in zip(colors, [0, 1], target_names):
    plt.scatter(X_r[y == i, 0], X_r[y == i, 1], 
                color=color, 
                alpha=alpha, 
                lw=lw,
                label=target_name)
plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('First two PCA directions');
ax = plt.subplot(1, 2, 2, projection='3d')

pca = PCA(n_components=3)
X_reduced = pca.fit(X).transform(X)
for color, i, target_name in zip(colors, [0, 1], target_names):
    ax.scatter(X_reduced[y == i, 0], X_reduced[y == i, 1], X_reduced[y == i, 2], 
               color=color,
               alpha=alpha,
               lw=lw, 
               label=target_name)
plt.legend(loc='best', shadow=False, scatterpoints=1)
ax.set_title("First three PCA directions")
ax.set_xlabel("1st")
ax.set_ylabel("2nd")
ax.set_zlabel("3rd")
ax.view_init(30, 10)

# %%
sc = StandardScaler()
X_train_std = sc.fit_transform(X_train)
pca = PCA(n_components=None)
x_train_pca = pca.fit_transform(X_train_std)
a = pca.explained_variance_ratio_
a_running = a.cumsum()
a_running
# Out:
# array([0.21243137, 0.31675805, 0.41064689, 0.49255011, 0.57170372,
#        0.64823654, 0.72214813, 0.79204483, 0.85466068, 0.91427319,
#        0.96840149, 0.99807208, 1.        ])

# %%
#Classification Models
# Gaussian Naive Bayes

# %%
gaussian = GaussianNB()
gaussian.fit(X_train, y_train)
y_pred = gaussian.predict(X_test)
score_gaussian = gaussian.score(X_test,y_test)
print('Accuracy of Gaussian Naive Bayes is', score_gaussian)
# Out:
# Accuracy of Gaussian Naive Bayes is 0.8235565110565111

# %%
#Linear Support Vector Machine

# %%
from sklearn.svm import SVC
svc = SVC(gamma=0.22)
svc.fit(X_train, y_train)
score_svc = svc.score(X_test,y_test)
print('Accuracy of SVC is', score_svc)
# Out:
# Accuracy of SVC is 0.7647420147420148

# %%
#Radical Support Vector Machine

# %%
svc_radical =svm.SVC(kernel='rbf',C=1,gamma=0.22)
svc_radical.fit(X_train,y_train.values.ravel())
score_svc_radical = svc_radical.score(X_test,y_test)
print('Accuracy of Radical SVC Model is', score_svc_radical)
# Out:
# Accuracy of Radical SVC Model is 0.7647420147420148

# %%
#LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
score_lr = lr.score(X_test,y_test)
print('Accuracy of the Logistic Regression is', score_lr)
# Out:
# Accuracy of the Logistic Regression is 0.8048218673218673

# %%
#Random Forest

# %%
rf = RandomForestClassifier()
rf .fit(X_train, y_train)
score_rf  = rf.score(X_test,y_test)
print('Accuracy of the Random Forest Model is', score_rf)
# Out:
# Accuracy of the Random Forest Model is 0.8570331695331695

# %%
#K-Nearest Neighbors

# %%
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
score_knn = knn.score(X_test,y_test)
print('Accuracy of the KNN Model is',score_knn)
# Out:
# Accuracy of the KNN Model is 0.7635135135135135

# %%
#Cross validation

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score 
from sklearn.model_selection import cross_val_predict

# %%
kfold = KFold(n_splits=10)
xyz=[]
accuracy=[]
std=[]
classifiers=['Naive Bayes','Linear Svm','Radial Svm','Logistic Regression','Decision Tree','KNN','Random Forest']
models=[GaussianNB(), svm.SVC(kernel='linear'),svm.SVC(kernel='rbf'),LogisticRegression(),DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors=9),RandomForestClassifier(n_estimators=100)]
for i in models:
    model = i
    cv_result = cross_val_score(model,X,y, cv = kfold,scoring = "accuracy")
    cv_result=cv_result
    xyz.append(cv_result.mean())
    std.append(cv_result.std())
    accuracy.append(cv_result)
models_dataframe=pd.DataFrame({'CV Mean':xyz,'Std':std},index=classifiers)       
models_dataframe
# Out:
#                       CV Mean       Std
# Naive Bayes          0.809244  0.004779
# Linear Svm           0.813790  0.004589
# Radial Svm           0.850399  0.006843
# Logistic Regression  0.826751  0.004755
# Decision Tree        0.807709  0.005751
# KNN                  0.839527  0.005408
# Random Forest        0.852733  0.005110

# %%
#We see that Random Forest is the most accurate model with an accuracy of 0.8591830466830467

# %%
#Grid Search CV

# %%
model = RandomForestClassifier()
parameters = {'n_estimators': [500], 'max_features': ['log2', 'sqrt','auto']}
                                               
#The number of features to consider when looking for the best split 'max_depth': [50,80,100,150], 'min_samples_split': [5,7,9,11], } grid_obj = GridSearchCV(model, parameters, scoring="neg_log_loss",n_jobs=4,cv = 5) grid_obj = grid_obj.fit(X_train,y_train) model_params = grid_obj.best_params_ model_params

# %%
rfc = RandomForestClassifier()

forest_params = [{'max_depth': list(range(10, 15)), 'max_features': list(range(0,14))}]

clf = GridSearchCV(rfc, forest_params, cv = 10, scoring='accuracy')

clf.fit(X_train, y_train)

print(clf.best_params_)

print(clf.best_score_)
# Out:
# {'max_depth': 12, 'max_features': 4}
# 0.8637131122649047

# %%
#Hence we have got the best score as 0.8637131122649047
